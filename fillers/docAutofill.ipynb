# %%
from pypdf import PdfReader, PdfWriter
from pypdf.generic import NameObject
import fitz  # PyMuPDF

# %%
from pypdf import PdfReader

reader = PdfReader("../inputs/form.pdf")
page = reader.pages[0]
print(page.extract_text())

# # extract only text oriented up
# print(page.extract_text(0))

# # extract text oriented up and turned left
# print(page.extract_text((0, 90)))

# # extract text in a fixed width format that closely adheres to the rendered
# # layout in the source pdf
# print(page.extract_text(extraction_mode="layout"))

# # extract text preserving horizontal positioning without excess vertical
# # whitespace (removes blank and "whitespace only" lines)
# print(page.extract_text(extraction_mode="layout", layout_mode_space_vertically=False))

# # adjust horizontal spacing
# print(page.extract_text(extraction_mode="layout", layout_mode_scale_weight=1.0))

# # exclude (default) or include (as shown below) text rotated w.r.t. the page
# print(page.extract_text(extraction_mode="layout", layout_mode_strip_rotated=False))
# Out:
#
#
# Solicitud de autorización de
# estancia y prórrogas
# (LO 4/2000 y RD 557/2011)
#
# EX-00
# 03
#
#
#
#
#
# 1) DATOS DEL EXTRANJERO/A
#
# PASAPORTE           N.I.E..E  --        -
#
# 1er Apellido  2º Apellido
#
# Nombre  Sexo(1) H  M
#
# Fecha de nacimiento(2)      Lugar  País
#
# Nacionalidad  Estado civil(3) S  C  V  D  Sp
#
# Nombre del padre  Nombre de la madre
#
# Domicilio en España  Nº  Piso
#
# Localidad  C.P.  Provincia
#
# Teléfono móvil           E-mail
# Representante legal, en su caso  DNI/NIE/PAS  Título(4)
#
#
#
#
# 2) DATOS DEL REPRESENTANTE A EFECTOS DE PRESENTACIÓN DE LA SOLICITUD (5)
#
# Nombre/Razón Social  DNI/NIE/PAS
#
# Domicilio en España  Nº  Piso
#
# Localidad  C.P.  Provincia
#
# Teléfono móvil           E-mail
#
# Representante legal, en su caso  DNI/NIE/PAS  Título(4)
#
#
#
# 3) DOMICILIO A EFECTOS DE NOTIFICACIONES
#
# Nombre/Razón Social  DNI/NIE/PAS
#
# Domicilio en España  Nº  Piso
#
# Localidad  C.P.  Provincia
#
# Teléfono móvil           E-mail
#
#
#
#
# □ CONSIENTO que las comunicaciones y notificaciones se realicen por medios (6)
# Espacios para sellos
# de registro

# %%
import os
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: c:\Users\sebas\Desktop\DevProject\startup_seal\seal\fillers

# %%
import os

file_path = r"..\inputs\form.pdf"
abs_path = os.path.abspath(file_path)
print(f"Looking for file at: {abs_path}")
# Out:
# Looking for file at: c:\Users\sebas\Desktop\DevProject\startup_seal\seal\inputs\form.pdf

# %%
# Load the PDF document
reader = PdfReader("../inputs/form.pdf")

# Retrieve the form fields; this returns a dictionary where keys are field names.
fields = reader.get_fields()

# Check if any fields were found
if fields:
    print("Form fields found in the document:")
    for field_name, field_info in fields.items():
        print(f"Field Name: {field_name}")
        print("Field Info:")
        for key, value in field_info.items():
            print(f"  {key}: {value}")
        print("-" * 40)
else:
    print("No form fields found in the document.")
# Out:
# Form fields found in the document:
# Field Name: PASAPORTE
# Field Info:
#   /T: PASAPORTE
#   /FT: /Tx
#   /TU: PASAPORTE
# ----------------------------------------
# Field Name: NIE
# Field Info:
#   /T: NIE
#   /FT: /Tx
#   /TU: N.I.E
# ----------------------------------------
# Field Name: nie_principal
# Field Info:
#   /T: nie_principal
#   /FT: /Tx
#   /TU: Causa baja por cese
# ----------------------------------------
# Field Name: NIE_2
# Field Info:
#   /T: NIE_2
#   /FT: /Tx
#   /TU: N.I.E
# ----------------------------------------
# Field Name: 1er Apellido
# Field Info:
#   /T: 1er Apellido
#   /FT: /Tx
#   /TU: 1er Apellido
# ----------------------------------------
# Field Name: 2 Apellido
# Field Info:
#   /T: 2 Apellido
#   /FT: /Tx
#   /TU: 1er Apellido
# ----------------------------------------
# Field Name: Nombre
# Field Info:
#   /T: Nombre
#   /FT: /Tx
#   /TU: Nombre
# ----------------------------------------
# Field Name: Sexo
# Field Info:
#   /T: Sexo
#   /FT: /Btn
#   /Ff: 49152
#   /Kids: [IndirectObject(774, 0, 1793612759984), IndirectObject(775, 0, 1793612759984)]
#   /_States_: ['/Hombre', '/Mujer']
# ----------------------------------------
# Field Name: Dia_Nacimiento
# Field Info:
#   /T: Dia_Nacimiento
#   /FT: /Tx
#   /AA: {'/F': IndirectObject(848, 0, 1793612759984), '/K': IndirectObject(849, 0, 1793612759984)}
# ----------------------------------------
# Field Name: Mes_Nacimiento
# Field Info:
#   /T: Mes_Nacimiento
#   /FT: /Tx
#   /AA: {'/F': IndirectObject(850, 0, 1793612759984), '/K': IndirectObject(851, 0, 1793612759984)}
# ----------------------------------------
# Field Name: Año_Nacimiento
# Field Info:
#   /T: Año_Nacimiento
#   /FT: /Tx
#   /TU: undefined
#   /AA: {'/F': IndirectObject(852, 0, 1793612759984), '/K': IndirectObject(853, 0, 1793612759984)}
# ----------------------------------------
# Field Name: Lugar
# Field Info:
#   /T: Lugar
#   /FT: /Tx
#   /TU: Lugar
# ----------------------------------------
# Field Name: Pais
# Field Info:
#   /T: Pais
#   /FT: /Tx
# ----------------------------------------
# Field Name: Nacionalidad
# Field Info:
#   /T: Nacionalidad
#   /FT: /Tx
#   /TU: Nacionalidad
# ----------------------------------------
# Field Name: Estado Civil
# Field Info:
#   /T: Estado Civil
#   /FT: /Btn
#   /Ff: 49152
#   /Kids: [IndirectObject(782, 0, 1793612759984), IndirectObject(783, 0, 1793612759984), IndirectObject(784, 0, 1793612759984), IndirectObject(785, 0, 1793612759984), IndirectObject(786, 0, 1793612759984)]
#   /_States_: ['/Soltero', '/Casado', '/Viudo', '/Divorciado', '/Separado']
# ----------------------------------------
# Field Name: Nombre del padre
# Field Info:
#   /T: Nombre del padre
#   /FT: /Tx
#   /TU: Nombre del padre
# ----------------------------------------
# Field Name: Nombre de la madre
# Field Info:
#   /T: Nombre de la madre
#   /FT: /Tx
#   /TU: Nombre de la madre
# ----------------------------------------
# Field Name: Domicilio en España
# Field Info:
#   /T: Domicilio en España
#   /FT: /Tx
#   /TU: Domicilio en España
# ----------------------------------------
# Field Name: Numero
# Field Info:
#   /T: Numero
#   /FT: /Tx
# ----------------------------------------
# Field Name: Piso_extranjero
# Field Info:
#   /T: Piso_extranjero
#   /FT: /Tx
#   /TU: Piso
# ----------------------------------------
# Field Name: Localidad
# Field Info:
#   /T: Localidad
#   /FT: /Tx
#   /TU: Localidad
# ----------------------------------------
# Field Name: CP
# Field Info:
#   /T: CP
#   /FT: /Tx
#   /TU: C.P
# ----------------------------------------
# Field Name: Teléfono móvil
# Field Info:
#   /T: Teléfono móvil
#   /FT: /Tx
#   /TU: Teléfono móvil
# ----------------------------------------
# Field Name: email
# Field Info:
#   /T: email
#   /FT: /Tx
# ----------------------------------------
# Field Name: Representante legal en su caso
# Field Info:
#   /T: Representante legal en su caso
#   /FT: /Tx
#   /TU: Representante legal, en su caso
# ----------------------------------------
# Field Name: DNINIEPAS
# Field Info:
#   /T: DNINIEPAS
#   /FT: /Tx
#   /TU: DNI/NIE/PAS
# ----------------------------------------
# Field Name: titulo
# Field Info:
#   /T: titulo
#   /FT: /Tx
# ----------------------------------------
# Field Name: NombreRazón Social
# Field Info:
#   /T: NombreRazón Social
#   /FT: /Tx
#   /TU: Nombre/Razón Social
# ----------------------------------------
# Field Name: DNINIEPAS_representante
# Field Info:
#   /T: DNINIEPAS_representante
#   /FT: /Tx
#   /TU: DNI/NIE/PAS
# ----------------------------------------
# Field Name: Domicilio en España_2
# Field Info:
#   /T: Domicilio en España_2
#   /FT: /Tx
#   /TU: Domicilio en España
# ----------------------------------------
# Field Name: N
# Field Info:
#   /T: N
#   /FT: /Tx
#   /TU: N
# ----------------------------------------
# Field Name: Piso
# Field Info:
#   /T: Piso
#   /FT: /Tx
#   /TU: Piso
# ----------------------------------------
# Field Name: Localidad_2
# Field Info:
#   /T: Localidad_2
#   /FT: /Tx
#   /TU: Localidad
# ----------------------------------------
# Field Name: CP_2
# Field Info:
#   /T: CP_2
#   /FT: /Tx
#   /TU: C.P
# ----------------------------------------
# Field Name: N Piso_representate
# Field Info:
#   /T: N Piso_representate
#   /FT: /Tx
#   /TU: Nº Piso_Row_1
# ----------------------------------------
# Field Name: Teléfono móvil_2
# Field Info:
#   /T: Teléfono móvil_2
#   /FT: /Tx
#   /TU: Teléfono móvil
# ----------------------------------------
# Field Name: email_representate
# Field Info:
#   /T: email_representate
#   /FT: /Tx
# ----------------------------------------
# Field Name: Representante legal en su caso_2
# Field Info:
#   /T: Representante legal en su caso_2
#   /FT: /Tx
#   /TU: Representante legal, en su caso
# ----------------------------------------
# Field Name: DNINIEPAS_2
# Field Info:
#   /T: DNINIEPAS_2
#   /FT: /Tx
#   /TU: DNI/NIE/PAS
# ----------------------------------------
# Field Name: titulo_representate
# Field Info:
#   /T: titulo_representate
#   /FT: /Tx
# ----------------------------------------
# Field Name: NombreRazón Social_2
# Field Info:
#   /T: NombreRazón Social_2
#   /FT: /Tx
#   /TU: Nombre/Razón Social
# ----------------------------------------
# Field Name: DNINIEPAS_Notificacio
# Field Info:
#   /T: DNINIEPAS_Notificacio
#   /FT: /Tx
#   /TU: DNI/NIE/PAS
# ----------------------------------------
# Field Name: Domicilio en España_3
# Field Info:
#   /T: Domicilio en España_3
#   /FT: /Tx
#   /TU: Domicilio en España
# ----------------------------------------
# Field Name: Numero_notificacion
# Field Info:
#   /T: Numero_notificacion
#   /FT: /Tx
#   /TU: N
# ----------------------------------------
# Field Name: N Piso
# Field Info:
#   /T: N Piso
#   /FT: /Tx
#   /TU: Nº Piso
# ----------------------------------------
# Field Name: Localidad_3
# Field Info:
#   /T: Localidad_3
#   /FT: /Tx
#   /TU: Localidad
# ----------------------------------------
# Field Name: CP_3
# Field Info:
#   /T: CP_3
#   /FT: /Tx
#   /TU: C.P
# ----------------------------------------
# Field Name: Provincia
# Field Info:
#   /T: Provincia
#   /FT: /Tx
#   /TU: Nº Piso_Row_1
#   /Kids: [IndirectObject(794, 0, 1793612759984), IndirectObject(820, 0, 1793612759984)]
# ----------------------------------------
# Field Name: Teléfono móvil_3
# Field Info:
#   /T: Teléfono móvil_3
#   /FT: /Tx
#   /TU: Teléfono móvil
# ----------------------------------------
# Field Name: email_notificacion
# Field Info:
#   /T: email_notificacion
#   /FT: /Tx
# ----------------------------------------
# Field Name: CONSIENTO que las comunicaciones y notificaciones se realicen por medios electrónicos 6
# Field Info:
#   /T: CONSIENTO que las comunicaciones y notificaciones se realicen por medios electrónicos 6
#   /FT: /Btn
#   /TU: CONSIENTO que las comunicaciones y notificaciones se realicen por medios electrónicos (6
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Nombre y apellidos del titular
# Field Info:
#   /T: Nombre y apellidos del titular
#   /FT: /Tx
#   /TU: Nombre y apellidos del titular
# ----------------------------------------
# Field Name: Incicial
# Field Info:
#   /T: Incicial
#   /FT: /Btn
#   /TU: RESIDENCIA TEMPORAL
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Estancia por estudios
# Field Info:
#   /T: Estancia por estudios
#   /FT: /Btn
#   /TU: Cónyuge
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Autorización de estancia por estudios superiores
# Field Info:
#   /T: Autorización de estancia por estudios superiores
#   /FT: /Btn
#   /TU: Pareja registrada
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Estudiante
# Field Info:
#   /T: Estudiante
#   /FT: /Btn
#   /TU: Descendiente <21 años
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Familiar de titular
# Field Info:
#   /T: Familiar de titular
#   /FT: /Btn
#   /TU: Descendiente >21 años a cargo o incapaz
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Estancia en base a instrucciones
# Field Info:
#   /T: Estancia en base a instrucciones
#   /FT: /Btn
#   /TU: Ascendiente a cargo
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Otros
# Field Info:
#   /T: Otros
#   /FT: /Btn
#   /TU: Ascendiente a cargo
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Otros Inicial
# Field Info:
#   /T: Otros Inicial
#   /FT: /Tx
# ----------------------------------------
# Field Name: Autorización de estancia por estudios no superiores
# Field Info:
#   /T: Autorización de estancia por estudios no superiores
#   /FT: /Btn
#   /TU: Pareja no registrada
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Formacion reglada
# Field Info:
#   /T: Formacion reglada
#   /FT: /Btn
#   /TU: Formacion reglada
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Prórroga
# Field Info:
#   /T: Prórroga
#   /FT: /Btn
#   /TU: RESIDENCIA TEMPORAL
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Titular de autorización
# Field Info:
#   /T: Titular de autorización
#   /FT: /Btn
#   /TU: Cónyuge
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Titular de visado
# Field Info:
#   /T: Titular de visado
#   /FT: /Btn
#   /TU: Pareja registrada
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Titular de autorización estancia por estudios
# Field Info:
#   /T: Titular de autorización estancia por estudios
#   /FT: /Btn
#   /TU: Pareja no registrada
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Familiar de titular de autorización voluntariado
# Field Info:
#   /T: Familiar de titular de autorización voluntariado
#   /FT: /Btn
#   /TU: Descendiente <21 años
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Familiar de titular régimen especial sanitario
# Field Info:
#   /T: Familiar de titular régimen especial sanitario
#   /FT: /Btn
#   /TU: Descendiente >21 años a cargo o incapaz
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Titular de autorización regimen especial sanitario
# Field Info:
#   /T: Titular de autorización regimen especial sanitario
#   /FT: /Btn
#   /TU: Ascendiente a cargo
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Titular de autorización por intramovilidad
# Field Info:
#   /T: Titular de autorización por intramovilidad
#   /FT: /Btn
#   /TU: Progenitor de ciudadano UE
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Titular de autorización por estudios superiores
# Field Info:
#   /T: Titular de autorización por estudios superiores
#   /FT: /Btn
#   /TU: Descendiente >21 años a cargo o incapaz
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Titular de autorización por estudios no superiores
# Field Info:
#   /T: Titular de autorización por estudios no superiores
#   /FT: /Btn
#   /TU: Ascendiente a cargo
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Menor desplazado por tratamiento médico
# Field Info:
#   /T: Menor desplazado por tratamiento médico
#   /FT: /Btn
#   /TU: Progenitor de ciudadano UE
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Menor desplazado para escolarización
# Field Info:
#   /T: Menor desplazado para escolarización
#   /FT: /Btn
#   /TU: Descendiente >21 años a cargo o incapaz
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Titular de autorización consejo de ministros
# Field Info:
#   /T: Titular de autorización consejo de ministros
#   /FT: /Btn
#   /TU: Ascendiente a cargo
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Titular de autorización de estancia
# Field Info:
#   /T: Titular de autorización de estancia
#   /FT: /Btn
#   /TU: Progenitor de ciudadano UE
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Titular de visado de estancia
# Field Info:
#   /T: Titular de visado de estancia
#   /FT: /Btn
#   /TU: Ascendiente a cargo
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Otros PROORGA
# Field Info:
#   /T: Otros PROORGA
#   /FT: /Btn
#   /TU: Ascendiente a cargo
#   /_States_: ['/On', '/Off']
# ----------------------------------------
# Field Name: Otros Prórroga
# Field Info:
#   /T: Otros Prórroga
#   /FT: /Tx
# ----------------------------------------
# Field Name: Motivos de justificacion
# Field Info:
#   /T: Motivos de justificacion
#   /FT: /Tx
#   /TU: Especificar la causa
# ----------------------------------------
# Field Name: Localidad_Firma
# Field Info:
#   /T: Localidad_Firma
#   /FT: /Tx
# ----------------------------------------
# Field Name: Dia_FIrma
# Field Info:
#   /T: Dia_FIrma
#   /FT: /Tx
#   /AA: {'/F': IndirectObject(885, 0, 1793612759984), '/K': IndirectObject(886, 0, 1793612759984)}
# ----------------------------------------
# Field Name: Mes_Firma
# Field Info:
#   /T: Mes_Firma
#   /FT: /Tx
# ----------------------------------------
# Field Name: Año_Firma
# Field Info:
#   /T: Año_Firma
#   /FT: /Tx
#   /AA: {'/F': IndirectObject(883, 0, 1793612759984), '/K': IndirectObject(884, 0, 1793612759984)}
# ----------------------------------------
# Field Name: Dirigido a
# Field Info:
#   /T: Dirigido a
#   /FT: /Tx
# ----------------------------------------
# Field Name: DIR3
# Field Info:
#   /T: DIR3
#   /FT: /Tx
# ----------------------------------------
# Field Name: Provincia dirigida a
# Field Info:
#   /T: Provincia dirigida a
#   /FT: /Tx
# ----------------------------------------

# %%
# Load the PDF
reader = PdfReader(r"..\inputs\form.pdf")
writer = PdfWriter()

# Copy all pages
for page in reader.pages:
    writer.add_page(page)

# Copy AcroForm dictionary
if "/AcroForm" in reader.trailer["/Root"]:
    writer._root_object.update({
        NameObject("/AcroForm"): reader.trailer["/Root"]["/AcroForm"]
    })

# DEBUG: Print all available form field names
fields = reader.get_fields()
print("Available Fields:")
for field_name in fields.keys():
    print(f"- {field_name}")

# FIELDS
pasaporte = "A3932179"
first_name = "Sebastian"
first_ln = "Perilla"
second_ln = "Espinosa"
NIE = "Y8865712P"
gender = "Hombre"  # Make sure this matches the available options
location = "Quito"
country = "Ecuador"
nationality = "Ecuadorian"
father_name = "Alfredo Perilla"
mother_name = "Maria Cristina Espinosa"
address_spain = "Calle Duque de Sevilla, 14"
postal_code = "28002"
mobile_phone = "+34617725525"
email = "sebastianperillaespinosa@gmail.com"



# Step 3: Update multiple field values correctly
writer.update_page_form_field_values(
    writer.pages[0],
    {
        "PASAPORTE": pasaporte,
        "Nombre": first_name,
        "NIE": "Y",
        "nie_principal": "665712",
        "NIE_2" : "P",
        "1er Apellido": first_ln,
        "2 Apellido": second_ln,  # Might be "2º Apellido" instead of "2 Apellido"
        "Sexo": gender,  # Ensure this matches available states
        "Email": email,
        "Lugar": location,
        "Pais": country,
        "Nacionalidad": nationality,
        "Nombre del padre": father_name,
        "Nombre de la madre": mother_name,
        "Domicilio en España": address_spain,
        "CP": postal_code,
        "Teléfono móvil": mobile_phone,
    }
)

# Set Need Appearances
writer.set_need_appearances_writer()

# Save the updated PDF
with open("modified.pdf", "wb") as output_stream:
    writer.write(output_stream)

print("Modified PDF saved as 'modified.pdf'.")

# Open the modified PDF that you've already updated.
doc = fitz.open("modified.pdf")

# Iterate over pages and overlay the field text onto the page.
for page in doc:
    # Get a list of widgets (form fields) on the page.
    widgets = page.widgets()
    if widgets:
        for widget in widgets:
            # If the widget has a value, overlay it on the page.
            if widget.field_value is not None:
                # Get the rectangle for the field.
                rect = widget.rect
                # Insert the text into the page content.
                # Adjust the position, font size, and color as needed.
                page.insert_text(
                    (rect.x0 + 50, rect.y0 + 15),  # A small offset may help visually.
                    widget.field_value,
                    fontsize=12,
                    color=(0, 0, 0)
                )
# Save the flattened PDF.
doc.save(r"C:\Users\sebas\Desktop\DevProject\startup_seal\seal\outputs\flattened.pdf")
print("Flattened PDF saved as 'flattened.pdf'.")
# Out:
# Available Fields:
# - PASAPORTE
# - NIE
# - nie_principal
# - NIE_2
# - 1er Apellido
# - 2 Apellido
# - Nombre
# - Sexo
# - Dia_Nacimiento
# - Mes_Nacimiento
# - Año_Nacimiento
# - Lugar
# - Pais
# - Nacionalidad
# - Estado Civil
# - Nombre del padre
# - Nombre de la madre
# - Domicilio en España
# - Numero
# - Piso_extranjero
# - Localidad
# - CP
# - Teléfono móvil
# - email
# - Representante legal en su caso
# - DNINIEPAS
# - titulo
# - NombreRazón Social
# - DNINIEPAS_representante
# - Domicilio en España_2
# - N
# - Piso
# - Localidad_2
# - CP_2
# - N Piso_representate
# - Teléfono móvil_2
# - email_representate
# - Representante legal en su caso_2
# - DNINIEPAS_2
# - titulo_representate
# - NombreRazón Social_2
# - DNINIEPAS_Notificacio
# - Domicilio en España_3
# - Numero_notificacion
# - N Piso
# - Localidad_3
# - CP_3
# - Provincia
# - Teléfono móvil_3
# - email_notificacion
# - CONSIENTO que las comunicaciones y notificaciones se realicen por medios electrónicos 6
# - Nombre y apellidos del titular
# - Incicial
# - Estancia por estudios
# - Autorización de estancia por estudios superiores
# - Estudiante
# - Familiar de titular
# - Estancia en base a instrucciones
# - Otros
# - Otros Inicial
# - Autorización de estancia por estudios no superiores
# - Formacion reglada
# - Prórroga
# - Titular de autorización
# - Titular de visado
# - Titular de autorización estancia por estudios
# - Familiar de titular de autorización voluntariado
# - Familiar de titular régimen especial sanitario
# - Titular de autorización regimen especial sanitario
# - Titular de autorización por intramovilidad
# - Titular de autorización por estudios superiores
# - Titular de autorización por estudios no superiores
# - Menor desplazado por tratamiento médico
# - Menor desplazado para escolarización
# - Titular de autorización consejo de ministros
# - Titular de autorización de estancia
# - Titular de visado de estancia
# - Otros PROORGA
# - Otros Prórroga
# - Motivos de justificacion
# - Localidad_Firma
# - Dia_FIrma
# - Mes_Firma
# - Año_Firma
# - Dirigido a
# - DIR3
# - Provincia dirigida a
# Modified PDF saved as 'modified.pdf'.
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# Flattened PDF saved as 'flattened.pdf'.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Open the modified PDF that you've already updated.
doc = fitz.open("modified.pdf")

# Iterate over pages and overlay the field text onto the page.
for page in doc:
    # Get a list of widgets (form fields) on the page.
    widgets = page.widgets()
    if widgets:
        for widget in widgets:
            # If the widget has a value, overlay it on the page.
            if widget.field_value is not None:
                # Get the rectangle for the field.
                rect = widget.rect
                # Insert the text into the page content.
                # Adjust the position, font size, and color as needed.
                page.insert_text(
                    (rect.x0 + 50, rect.y0 + 15),  # A small offset may help visually.
                    widget.field_value,
                    fontsize=12,
                    color=(0, 0, 0)
                )
# Save the flattened PDF.
doc.save("flattened.pdf")
print("Flattened PDF saved as 'flattened.pdf'.")
# Out:
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# MuPDF error: argument error: cannot create appearance stream for  widgets
#
# Flattened PDF saved as 'flattened.pdf'.
